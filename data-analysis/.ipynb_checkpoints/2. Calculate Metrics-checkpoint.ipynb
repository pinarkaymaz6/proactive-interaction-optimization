# %%
import pandas as pd
import datetime as dt

# %%
def calculate_metrics(conv_df, metric):
    try:
        start = conv_df['date'].iloc[0]
        end = conv_df[conv_df['end_conversation']==True].iloc[0]['date']
        duration = (end-start).seconds
        
        start_rating = conv_df[(conv_df['trigger']=='rating')&(conv_df['reaction']==False)].iloc[0]['date']
        end_rating = conv_df['date'].iloc[-1]
        duration_rating = (end_rating-start_rating).seconds
        duration+=duration_rating
        
    except:
         duration = (conv_df['date'].iloc[-1] - conv_df['date'].iloc[0]).seconds #rating sorusuna kadar gecen sure olmali
    metric['duration'] = duration
    #print(metric['duration'])
    metric['length'] = conv_df.shape[0]
    metric['initiatedByUser'] = not conv_df["from_is_bot"].iloc[0]
    metric['turnsByUser'] = (~conv_df['from_is_bot']).values.sum()
    free_text = conv_df[(conv_df['type']=='message')& (conv_df['is_command']==False)]['text']
    if free_text.any():
        metric['numWords'] = round(free_text.apply(lambda a: len(a.split())).mean(),4)
    else:
        metric['numWords']=0
    
    moodQ=0
    emotionQ =0
    ratingQ=0
    
    mood_ignored=0
    emo_ignored=0
    rating_ignored=0
    
    rr_mood = None
    rr_emotion = None
    rr_rating = None
    rd_mood = None
    rd_emotion = None
    rd_rating = None
    emo_count=0
    
    mask = (conv_df['trigger'] == 'cloud-scheduler') | (conv_df['trigger'] == 'command-save')
    length = conv_df[mask].shape[0]
    moodQ = length
    for index, row in conv_df[mask].iterrows():
        message_id = row["message_id"]
        mood_mask = (conv_df["message_id"] == message_id) & (conv_df["trigger"]=="mood-callback")
        response = conv_df[mood_mask]
        if len(response):
            response = response.iloc[0]
            mood = str(response["data"])
            if rr_mood:
                rr_mood +=1
            else:
                rr_mood = 1
            if rd_mood:
                rd_mood+=(response["date"]-row["date"]).seconds
            else:
                rd_mood = (response["date"]-row["date"]).seconds
            if "bad" in mood:
                emotionQ+=1
                emo_count+=1
                hook = response["hook"]
                emotion_request = conv_df[conv_df["hook"] == message_id].iloc[0]
                m_id = emotion_request["message_id"]
                emotion_response = conv_df[conv_df["message_id"] == m_id].loc[conv_df["trigger"]=="mood-callback"]
                if len(emotion_response):
                    emotion_response= emotion_response.iloc[0]
                    emotion = emotion_response["data"]
                    if emotion:
                        if rd_emotion:
                            rd_emotion +=(emotion_response["date"]-emotion_request["date"]).seconds
                        else:
                            rd_emotion =(emotion_response["date"]-emotion_request["date"]).seconds
                        if rr_emotion:
                            rr_emotion+=1
                        else:
                            rr_emotion=1
                else:
                    emo_ignored+=1
                    print("No response to emotion question", row["chat_id"], row["message_id"])
                    
        else:
            mood_ignored+=1
            print("No response to mood question", row["chat_id"], row["message_id"])
            #mood sorusuna cevap gelmemis demektir
    
    rating_mask = (conv_df['trigger'] == 'rating') & (conv_df['reaction'] == False)
    rating_length = conv_df[rating_mask].shape[0]
    ratingQ=rating_length
    for index, row in conv_df[rating_mask].iterrows():
        message_id = row["message_id"]
        callback_mask = (conv_df["message_id"] == message_id) & (conv_df["trigger"]=="rating-callback")
        rating_response = conv_df[callback_mask]
        if len(rating_response):
            rating_response= rating_response.iloc[0]
            raing = str(rating_response["data"])
            if rr_rating:
                rr_rating +=1
            else:
                rr_rating = 1
            if rd_rating:
                rd_rating+=(rating_response["date"]-row["date"]).seconds
            else:
                rd_rating = (rating_response["date"]-row["date"]).seconds
        else:
            rating_ignored+=1
            print("No response to rating question", row["chat_id"], row["message_id"])
            #rating sorusuna cevap gelmmemis demektir
            
            
    if rr_mood:
        metric["rr_mood"]=rr_mood/length
    else:
        metric["rr_mood"]=float("NaN")
    if rr_emotion:
        metric["rr_emotion"]=rr_emotion/emo_count
    else:
        metric["rr_emotion"]=float("NaN")
    if rr_rating:
        metric["rr_rating"]=rr_rating/rating_length
    else:
        metric["rr_rating"]=float("NaN")
    
    if rd_emotion:
        metric["rd_emotion"]=str(rd_emotion/emo_count).split(".")[0]
    else:
        metric["rd_emotion"]=float("NaN")
    if rd_mood:
        metric["rd_mood"] = str(rd_mood/length).split(".")[0]
    else:
        metric["rd_mood"] = float("NaN")
    if rd_rating:
        metric["rd_rating"] = str(rd_rating/rating_length).split(".")[0]
    else:
        metric["rd_rating"] = float("NaN")
    
    
    
    #RATING
    # Current : length is total number of replies
    # Alternative: length of all answered and not-answered questions 
    # Question: If the user didnt rate, do we include it into average? No.
    r_mask = (conv_df['trigger'] == 'rating-callback')
    r_length = conv_df[r_mask].shape[0]
    avg_rating =0
    if r_length:
        for index, row in conv_df[r_mask].iterrows():
            avg_rating+=int(row["data"])
        avg_rating = avg_rating/r_length
        metric["rating"]=avg_rating
    else:
        metric["rating"] = None 
    
    metric["RR"]=None
    metric["RD"]=None
    rr_total =0
    if rr_rating:
        rr_total+=rr_rating
    if rr_mood:
        rr_total+=rr_mood
    if rr_emotion:
        rr_total += rr_emotion
    
    rd_total =0
    if rd_rating:
        rd_total+= rd_rating
    if rd_mood:
        rd_total+= rd_mood
    if rd_emotion:
        rd_total+=rd_emotion
    
    try:
        metric["RR"] =round(rr_total/(moodQ+emotionQ+ratingQ), 2)
        metric["RD"] =round(rd_total/(moodQ+emotionQ+ratingQ), 2)
    except:
        print("divide by zero maybe")
    
    desc = {
        "mood_ignored":mood_ignored,
        "moodQ":moodQ,
        "emo_ignored":emo_ignored,
        "emotionQ":emotionQ,
        "rating_ignored":rating_ignored,
        "ratingQ":ratingQ
    }
    
    return metric, desc

# %%
desc_stats=list()
def get_metrics(df_all):
    all_metrics = list()
    for chat_id, chat_df in df_all.groupby('chat_id'):
        for conv_id, conv_df in chat_df.groupby('conv_id'):
            metric = dict()
            metric['usergroup']= chat_df['usergroup'].iloc[0]
            metric['chat_id']=chat_id
            metric['conv_id']=conv_id
            metric, desc = calculate_metrics(conv_df, metric)
            all_metrics.append(metric)
            desc_stats.append({"group": chat_df['usergroup'].iloc[0],"desc":desc})
    df_metrics = pd.DataFrame.from_records(all_metrics)
    df_metrics.fillna(value=pd.np.nan, inplace=True)
    return df_metrics

# %%
df_users = pd.read_csv('users.csv')
df_users
# Out:
#        chat_id     from_id                 start_date usergroup schedule  \
# 0     95008127    95008127  2020-03-21 13:09:04+01:00   default    09:00
# 1    162138505   162138505  2020-03-21 13:44:31+01:00    custom    16:00
# 2    905572285   905572285  2020-03-21 20:18:08+01:00   default    09:00
# 3    891239356   891239356  2020-03-23 11:02:04+01:00    custom    10:00
# 19  2020-04-17 12:15:57+02:00              42           1
# 20  2020-04-22 09:00:52+02:00              37           3
# 21  2020-05-29 20:13:54+02:00               0          37
# 22  2020-05-29 11:19:12+02:00               0          34
# 23  2020-05-08 21:23:34+02:00              20          13
# 24  2020-05-11 09:37:24+02:00              18           8
# 25  2020-05-18 16:48:31+02:00              11          16
# 26  2020-05-29 09:21:21+02:00               0          25
# 27  2020-05-29 10:01:09+02:00               0          25
# 28  2020-05-26 09:40:30+02:00               3          12
# 29  2020-05-26 21:33:18+02:00               2          13
# 30  2020-05-23 09:11:54+02:00               6           7
# 31  2020-05-29 19:07:56+02:00               0          13
# 32  2020-05-21 10:08:10+02:00               8           3
# 33  2020-05-29 17:57:09+02:00               0          11

# %%
df_messages = pd.read_csv('messages.csv')
df_messages['date'] = df_messages['date'].apply(lambda a:dt.datetime.strptime(a[:19], '%Y-%m-%d %H:%M:%S'))
df_messages['date'] = pd.to_datetime(df_messages['date'])
df_messages.head()
# Out:
#     chat_id    from_id  conv_id  \
# 0  95008127   95008127        1
# 1  95008127  939263885        1
# 2  95008127  939263885        1
# 3  95008127   95008127        1
# 4  95008127  939263885        1
#
#                                                 text                date  \
# 0                                             /start 2020-03-21 13:09:04
# 1  Welcome to the Mood Tracker! I am here to keep... 2020-03-21 13:09:05
# 2                            How is your mood today? 2020-03-21 13:09:06
# 3                                                NaN 2020-03-21 13:09:09
# 4              I am glad to hear that you feel good! 2020-03-21 13:09:10
#
#    data  message_id  hook        trigger  reaction  end_conversation  \
# 0   NaN        2491     0            NaN     False             False
# 1   NaN        2492     0  command-start     False             False
# 2   NaN        2493     0   command-save     False             False
# 3  good        2493     0  mood-callback     False             False
# 4   NaN        2494     0  feedback-mood      True              True
#
#    from_is_bot            type  is_command usergroup
# 0        False         message        True   default
# 1         True          result       False   default
# 2         True          result       False   default
# 3        False  callback_query       False   default
# 4         True          result       False   default

# %%
df_metrics = get_metrics(df_messages)
df_metrics.head()
# Out:
# No response to mood question 95008127 3074
# No response to mood question 95008127 3201
# No response to rating question 105121899 3853
# No response to rating question 105121899 3860
# No response to rating question 105121899 4170
# No response to rating question 105121899 4296
# No response to mood question 105121899 4370
# No response to mood question 105121899 4455
# No response to rating question 131217570 3442
# No response to rating question 131217570 3630
# No response to rating question 131217570 3699
# No response to rating question 131217570 3711
# No response to mood question 131217570 3824
# No response to mood question 131217570 4003
# No response to mood question 131217570 4154
# No response to mood question 131217570 4270
# No response to mood question 131217570 4369
# No response to mood question 131217570 4454
# No response to mood question 131217570 4517
# No response to mood question 131217570 4622
# No response to mood question 131217570 4739
# No response to mood question 131217570 4859
# No response to mood question 131217570 4949
# No response to mood question 131217570 5081
# No response to mood question 131217570 5165
# No response to mood question 131217570 5293
# No response to mood question 131217570 5378
# No response to mood question 131217570 5474
# No response to mood question 131217570 5575
# No response to mood question 131217570 5649
# No response to mood question 131217570 5751
# No response to mood question 131217570 5865
# No response to mood question 131217570 5966
# No response to mood question 131217570 6081
# No response to mood question 131217570 6211
# No response to mood question 131217570 6281
# No response to mood question 131217570 6379
# No response to mood question 131217570 6594
# No response to mood question 131217570 6678
# No response to mood question 131217570 6788
# No response to mood question 131217570 6884
# No response to mood question 131217570 6982
# No response to mood question 131217570 7091
# No response to mood question 131217570 7198
# No response to mood question 131217570 7297
# No response to mood question 131217570 7421
# No response to mood question 131217570 7547
# No response to mood question 131217570 7676
# No response to mood question 131217570 7773
# No response to mood question 131217570 7860
# No response to mood question 131217570 7988
# No response to mood question 131217570 8067
# No response to mood question 131217570 8175
# No response to mood question 131217570 8248
# No response to mood question 131217570 8333
# No response to mood question 131217570 8404
# No response to rating question 152676961 7912
# No response to mood question 152676961 7923
# No response to mood question 152676961 8007
# No response to mood question 152676961 8120
# No response to mood question 152676961 8197
# No response to mood question 152676961 8282
# No response to mood question 152676961 8348
# No response to mood question 152676961 8445
# No response to mood question 162138505 3069
# No response to rating question 177635781 3483
# No response to rating question 177635781 3488
# No response to rating question 177635781 3562
# No response to rating question 177635781 3596
# No response to rating question 177635781 3603
# No response to rating question 177635781 3838
# No response to rating question 177635781 3847
# No response to rating question 177635781 4034
# No response to emotion question 177635781 5965
# No response to rating question 177635781 6073
# No response to mood question 177635781 6080
# No response to mood question 177635781 6210
# No response to mood question 177635781 6280
# No response to mood question 177635781 6378
# No response to mood question 177635781 6593
# No response to mood question 279331946 7508
# No response to rating question 279331946 7518
# No response to mood question 391209184 8297
# No response to mood question 391209184 8371
# No response to mood question 409808468 4183
# No response to mood question 409808468 4293
# No response to mood question 409808468 4394
# No response to mood question 409808468 4478
# No response to mood question 409808468 4542
# No response to mood question 409808468 4640
# No response to mood question 409808468 4749
# No response to mood question 409808468 4870
# No response to mood question 409808468 4998
# No response to mood question 409808468 5103
# No response to mood question 409808468 5228
# No response to mood question 409808468 5327
# No response to mood question 409808468 5398
# No response to mood question 409808468 5539
# No response to mood question 409808468 5592
# No response to mood question 409808468 5665
# No response to mood question 409808468 5779
# No response to mood question 409808468 5916
# No response to mood question 409808468 6016
# No response to mood question 409808468 6115
# No response to mood question 409808468 6238
# No response to mood question 409808468 6310
# No response to mood question 409808468 6409
# No response to mood question 409808468 6635
# No response to mood question 409808468 6717
# No response to mood question 409808468 6827
# No response to mood question 409808468 6916
# No response to mood question 409808468 7029
# No response to mood question 409808468 7147
# No response to mood question 409808468 7244
# No response to mood question 409808468 7342
# No response to mood question 409808468 7470
# No response to mood question 409808468 7598
# No response to mood question 409808468 7711
# No response to mood question 409808468 7806
# No response to mood question 409808468 7924
# No response to mood question 409808468 8008
# No response to mood question 409808468 8121
# No response to mood question 409808468 8198
# No response to mood question 409808468 8283
# No response to mood question 409808468 8349
# No response to mood question 409808468 8446
# No response to mood question 533137038 5826
# No response to mood question 533137038 5948
# No response to mood question 533137038 6058
# No response to mood question 533137038 6143
# No response to mood question 533137038 6262
# No response to mood question 533137038 6338
# No response to mood question 533137038 6577
# No response to mood question 533137038 6663
# No response to mood question 533137038 6776
# No response to mood question 533137038 6873
# No response to mood question 533137038 6957
# No response to mood question 533137038 7078
# No response to mood question 533137038 7186
# No response to mood question 533137038 7272
# No response to mood question 533137038 7376
# No response to mood question 533137038 7526
# No response to mood question 533137038 7647
# No response to mood question 533137038 7739
# No response to mood question 533137038 7839
# No response to mood question 533137038 7958
# No response to rating question 905572285 3845
# No response to rating question 905572285 4302
# No response to rating question 905572285 5226
# No response to rating question 905572285 5451
# No response to rating question 905572285 5525
# No response to rating question 905572285 5670
# No response to rating question 905572285 5782
# No response to rating question 905572285 5912
# No response to rating question 905572285 6119
# No response to rating question 905572285 6236
# No response to rating question 905572285 6293
# No response to rating question 905572285 6559
# No response to rating question 905572285 6632
# No response to rating question 905572285 6706
# No response to rating question 905572285 6825
# No response to rating question 905572285 7112
# No response to rating question 905572285 7471
# No response to mood question 905572285 7544
# No response to mood question 905572285 7673
# No response to mood question 905572285 7770
# No response to mood question 905572285 7857
# No response to mood question 905572285 7985
# No response to mood question 905572285 8064
# No response to mood question 905572285 8172
# No response to mood question 905572285 8245
# No response to mood question 905572285 8330
# No response to mood question 905572285 8401
# No response to emotion question 929690817 3647
# No response to rating question 929690817 3718
# No response to mood question 929690817 3778
# No response to mood question 929690817 4102
# No response to rating question 929690817 4240
# No response to mood question 929690817 4324
# No response to rating question 929690817 4595
# No response to mood question 929690817 4600
# No response to mood question 929690817 4694
# No response to mood question 929690817 4805
# No response to mood question 929690817 4929
# No response to mood question 929690817 5034
# No response to mood question 929690817 5144
# No response to mood question 929690817 5276
# No response to mood question 929690817 5356
# No response to mood question 929690817 5460
# No response to mood question 929690817 5560
# No response to mood question 929690817 5629
# No response to mood question 929690817 5717
# No response to mood question 929690817 5825
# No response to mood question 929690817 5947
# No response to mood question 929690817 6057
# No response to mood question 929690817 6142
# No response to mood question 929690817 6261
# No response to mood question 929690817 6337
# No response to mood question 929690817 6576
# No response to mood question 929690817 6662
# No response to mood question 929690817 6775
# No response to mood question 929690817 6872
# No response to mood question 929690817 6956
# No response to mood question 929690817 7077
# No response to mood question 929690817 7185
# No response to mood question 929690817 7271
# No response to mood question 929690817 7375
# No response to mood question 929690817 7525
# No response to mood question 929690817 7646
# No response to mood question 929690817 7738
# No response to mood question 929690817 7838
# No response to mood question 929690817 7957
# No response to mood question 929690817 8030
# No response to mood question 929690817 8145
# No response to mood question 929690817 8228
# No response to mood question 929690817 8313
# No response to mood question 929690817 8393
# No response to mood question 929690817 8530
# No response to rating question 995172882 7416
# No response to rating question 995172882 7435
# No response to rating question 995172882 7704
# No response to mood question 995172882 7782
# No response to mood question 995172882 7869
# No response to mood question 995172882 7997
# No response to mood question 995172882 8076
# No response to mood question 995172882 8183
# No response to mood question 995172882 8256
# No response to mood question 995172882 8341
# No response to mood question 995172882 8412
# No response to rating question 1018834281 7493
# No response to rating question 1018834281 7819
# No response to mood question 1018834281 7820
# No response to mood question 1018834281 7927
# No response to rating question 1018834281 8142
# No response to rating question 1018834281 8239
# No response to mood question 1018834281 8285
# No response to mood question 1018834281 8367
# No response to mood question 1018834281 8448
# No response to mood question 1042605234 4575
# No response to mood question 1042605234 4644
# No response to mood question 1042605234 4773
# No response to mood question 1042605234 4912
# No response to mood question 1042605234 5003
# No response to mood question 1042605234 5118
# No response to mood question 1042605234 5261
# No response to mood question 1042605234 5333
# No response to mood question 1042605234 5439
# No response to mood question 1042605234 5546
# No response to mood question 1042605234 5599
# No response to mood question 1042605234 5703
# No response to mood question 1042605234 5797
# No response to rating question 1234925460 6730
# No response to rating question 1234925460 6943
# No response to mood question 1234925460 7033
# No response to rating question 1234925460 7161
# No response to rating question 1234925460 7371
# No response to mood question 1249323037 4519
# No response to mood question 1249323037 4624
# No response to mood question 1249323037 4741
# No response to mood question 1249323037 4861
# No response to mood question 1249323037 4951
# No response to mood question 1249323037 5083
# No response to mood question 1249323037 5167
# No response to mood question 1249323037 5295
# No response to mood question 1249323037 5380
# No response to mood question 1249323037 5476
# No response to mood question 1249323037 5577
# No response to mood question 1249323037 5651
# No response to mood question 1249323037 5753
# No response to mood question 1249323037 5867
# No response to mood question 1249323037 5968
# No response to mood question 1249323037 6083
# No response to mood question 1249323037 6213
# No response to mood question 1249323037 6283
# No response to mood question 1249323037 6381
# No response to mood question 1249323037 6596
# No response to mood question 1249323037 6680
# No response to mood question 1249323037 6790
# No response to mood question 1249323037 6886
# No response to mood question 1249323037 6984
# No response to mood question 1249323037 7093
# No response to mood question 1249323037 7200
# No response to mood question 1249323037 7299
# No response to mood question 1249323037 7423
# No response to mood question 1249323037 7549
# No response to mood question 1249323037 7678
# No response to mood question 1249323037 7775
# No response to mood question 1249323037 7862
# No response to mood question 1249323037 7990
# No response to mood question 1249323037 8069
# No response to mood question 1280374122 7305
# No response to mood question 1280374122 7429
# No response to mood question 1280374122 7555
# No response to mood question 1280374122 7684
# No response to rating question 1280374122 7875
# No response to mood question 1280374122 7996
# No response to mood question 1280374122 8075
# No response to mood question 1280374122 8182
# No response to mood question 1280374122 8255
# No response to mood question 1280374122 8340
# No response to mood question 1280374122 8411
#        RD   RR   chat_id  conv_id  duration  initiatedByUser  length  \
# 0    9.50  1.0  95008127        1        23             True       8
# 1   11.00  1.0  95008127        2        77             True       8
# 2   19.67  1.0  95008127        3        66            False      11
# 3  164.00  1.0  95008127        4       844             True       9
# 4  152.67  1.0  95008127        5       490             True      11
#
#    numWords  rating rd_emotion rd_mood rd_rating  rr_emotion  rr_mood  \
# 0       0.0     4.0        NaN       3        16         NaN      1.0
# 1       2.0     5.0        NaN     NaN        11         NaN      NaN
# 2       0.0     4.0          8      16        35         1.0      1.0
# 3       4.0     5.0        NaN     NaN       164         NaN      NaN
# 4       4.0     4.0          5     450         3         1.0      1.0
#
#    rr_rating  turnsByUser usergroup
# 0        1.0            3   default
# 1        1.0            3   default
# 2        1.0            4   default
# 3        1.0            4   default
# 4        1.0            5   default

# %%
print(len(df_metrics))
# Out:
# 762

# %%
df_metrics_compact=df_metrics[["usergroup","chat_id","conv_id","RR","RD","rating","duration", "initiatedByUser", "length", "turnsByUser","numWords" ]]
df_metrics_compact # Fillna then save
# Out:
#     usergroup     chat_id  conv_id    RR        RD  rating  duration  \
# 0     default    95008127        1  1.00      9.50     4.0        23
# 1     default    95008127        2  1.00     11.00     5.0        77
# 2     default    95008127        3  1.00     19.67     4.0        66
# 3     default    95008127        4  1.00    164.00     5.0       844
# 4     default    95008127        5  1.00    152.67     4.0       490
# 5     default    95008127        6  1.00      3.00     4.0        54
# 6     default    95008127        7  1.00   1438.50     5.0      2878
# 7     default    95008127        8  1.00     17.00     4.0        33
# 8     default    95008127        9  1.00      9.00     4.0        11
# 9     default    95008127       10  1.00    186.50     5.0       378
# 10    default    95008127       11  1.00     11.00     5.0      1834
# 11    default    95008127       12  1.00     16.00     4.0        26
# 12    default    95008127       13  1.00      3.00     4.0       268
# 13    default    95008127       14  1.00     23.67     4.0        86
# 14    default    95008127       15  1.00     12.00     5.0        40
# 15    default    95008127       16  1.00     12.00     5.0        51
# 16    default    95008127       17  1.00     14.50     5.0       577
# 17    default    95008127       18  1.00     14.00     5.0        30
# 18    default    95008127       19  1.00    113.00     4.0       228
# 19    default    95008127       20  1.00     14.00     5.0        30
# 20    default    95008127       21  1.00   3446.00     4.0     10340
# 21    default    95008127       22  1.00   6372.67     5.0     19121
# 22    default    95008127       23  1.00   6538.50     5.0     13079
# 23    default    95008127       24  1.00   4475.00     4.0      8952
# 24    default    95008127       25  1.00    127.00     4.0       140
# 25    default    95008127       26  1.00      9.00     5.0        12
# 26    default    95008127       27  1.00    362.00     4.0       425
# 27    default    95008127       28  1.00    443.00     5.0      2724
# 28    default    95008127       29  1.00      9.00     4.0      1128
# 29    default    95008127       30  1.00    497.00     4.0      2846
# ..        ...         ...      ...   ...       ...     ...       ...
# 732    custom  1268414753       16  1.00    142.00     5.0       285
# 733    custom  1268414753       17  1.00    491.67     5.0      1477
# 734    custom  1268414753       18  1.00    139.33     5.0       325
# 735    custom  1268414753       19  1.00    433.50     5.0       867
# 736    custom  1268414753       20  1.00    948.00     5.0      1898
# 737    custom  1268414753       21  1.00    370.50     5.0       742
# 738    custom  1268414753       22  1.00    348.50     5.0       698
# 739    custom  1268414753       23  1.00    529.83     5.0      1129
# 740    custom  1268414753       24  1.00    682.75     5.0      2644
# 741    custom  1268414753       25  1.00    184.00     5.0       371
# 742    custom  1268414753       26  1.00    541.00     5.0      1083
# 743    custom  1268414753       27  1.00  21508.75     5.0     85642
# 744    custom  1268414753       28  1.00    775.50     5.0      1552
# 745    custom  1268414753       29  1.00   1472.50     5.0      2946
# 746    custom  1268414753       30  1.00   1663.50     5.0      3327
# 747    custom  1268414753       31  1.00    666.50     5.0      1336
# 748    custom  1268414753       32  1.00    625.67     5.0      1252
# 749    custom  1268414753       33  1.00    151.33     5.0       455
# 750    custom  1268414753       34  1.00   1075.50     5.0      2151
# 751    custom  1268414753       35  1.00    565.00     5.0      1131
# 752    custom  1268414753       36  1.00    723.00     5.0      1447
# 753    custom  1268414753       37  1.00  43192.50     5.0     86386
# 754    custom  1268414753       38  1.00    659.00     5.0      1318
# 755    custom  1268414753       39  1.00  43410.50     5.0     86821
# 756    custom  1268414753       40  1.00    626.50     5.0      1255
# 757   default  1280374122        1  1.00     14.50     5.0       290
# 758   default  1280374122        2  1.00   1067.50     4.0      2147
# 759   default  1280374122        3  0.33   6448.00     4.0     38695
# 760   default  1280374122        4  0.67    232.00     NaN       696
# 761   default  1280374122        5  0.00      0.00     NaN         1
#
#      initiatedByUser  length  turnsByUser  numWords
# 0               True       8            3    0.0000
# 1               True       8            3    2.0000
# 2              False      11            4    0.0000
# 3               True       9            4    4.0000
# 4               True      11            5    4.0000
# 5               True      14            6    1.0000
# 6              False       6            2    0.0000
# 7               True       5            2    4.0000
# 8               True       5            2    4.0000
# 9              False       9            3    0.0000
# 10              True      17            8    4.0000
# 11              True       5            2    4.0000
# 12              True      17            8    3.4286
# 13             False      11            4    0.0000
# 14              True       9            4    1.0000
# 15              True       9            4    2.6667
# 16              True      37           17    3.6250
# 17             False       6            2    0.0000
# 18             False       6            2    0.0000
# 19             False       6            2    0.0000
# 20             False       8            3    0.0000
# 21             False       8            3    0.0000
# 22             False       6            2    0.0000
# 23             False       6            2    0.0000
# 24              True       5            2    7.0000
# 25              True       5            2    7.0000
# 26              True       7            3    2.0000
# 27              True      21           10    3.1111
# 28              True      19            9    2.8750
# 29              True      47           23    4.0000
# ..               ...     ...          ...       ...
# 732            False       6            2    0.0000
# 733            False       8            3    0.0000
# 734            False       9            3    0.0000
# 735            False       6            2    0.0000
# 736            False       6            2    0.0000
# 737            False       6            2    0.0000
# 738            False       6            2    0.0000
# 739            False      16            6    0.0000
# 740            False      12            4    0.0000
# 741            False       6            2    0.0000
# 742            False       6            2    0.0000
# 743            False      11            4    0.0000
# 744            False       6            2    0.0000
# 745            False       6            2    0.0000
# 746            False       6            2    0.0000
# 747            False       6            2    0.0000
# 748            False       9            3    0.0000
# 749            False       8            3    0.0000
# 750            False       6            2    0.0000
# 751            False       6            2    0.0000
# 752            False       6            2    0.0000
# 753            False       6            2    0.0000
# 754            False       6            2    0.0000
# 755            False       6            2    0.0000
# 756            False       6            2    0.0000
# 757             True      14            6    2.6667
# 758            False       8            3    1.0000
# 759            False      10            2    0.0000
# 760            False       6            2    0.0000
# 761            False       6            0    0.0000
#
# [762 rows x 11 columns]

# %%
mood_total=0
mood_ignored=0
emo_total=0
emo_ignored=0
rating_ignored=0
rating_total=0

custom_mood_total=0
custom_mood_ignored=0
custom_emo_total=0
custom_emo_ignored=0
custom_rating_ignored=0
custom_rating_total=0
for conv in desc_stats:
    group = conv.get("group")
    desc=conv.get('desc')
    if group =='default':
        mood_ignored+=desc.get("mood_ignored")
        mood_total+=desc.get("moodQ")
        emo_ignored+=desc.get("emo_ignored")
        emo_total+=desc.get("emotionQ")
        rating_ignored+=desc.get("rating_ignored")
        rating_total+=desc.get("ratingQ")
    else:
        custom_mood_ignored+=desc.get("mood_ignored")
        custom_mood_total+=desc.get("moodQ")
        custom_emo_ignored+=desc.get("emo_ignored")
        custom_emo_total+=desc.get("emotionQ")
        custom_rating_ignored+=desc.get("rating_ignored")
        custom_rating_total+=desc.get("ratingQ")

ignored = [
    {"M":mood_total, "MI":mood_ignored, "E":emo_total, "EI": emo_ignored, 
     "R":rating_total, "RI":rating_ignored, "usergroup":"default"},
    {"M":custom_mood_total, "MI":custom_mood_ignored, "E":custom_emo_total, "EI": custom_emo_ignored, 
     "R":custom_rating_total, "RI":custom_rating_ignored, "usergroup":"custom"}
]

ignored_df = pd.DataFrame(ignored)
ignored_df
# Out:
#     E  EI    M   MI    R  RI usergroup
# 0  94   1  621  213  367  66   default
# 1  69   1  665  267  377  57    custom

# %%
df_metrics.to_csv('metrics_raw.csv', index=False)

# %%
df_metrics_compact.to_csv('metrics_compact.csv', index=False)

# %%
ignored_df.to_csv('ignored.csv', index=False)
